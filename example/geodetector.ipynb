# %%
import pandas as pd 
import spatbox as stx  
from spatbox.analysis.GD import geodetector as gd 
df = pd.read_csv(stx.utils.get_path('disease'))
example = gd.GeoDetector(df,["type", "region", "level"], "incidence")
example.plot() 
example.plot_interaction() 
result = example.interaction_detect()
